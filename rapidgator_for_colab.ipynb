# %% [markdown]
# # RapidGator Colab Downloader
# Use this notebook to download Rapidgator files with live progress.

# %%
# !pip -q install requests lxml
# !wget -q https://raw.githubusercontent.com/rcks750/RapidGator/main/rgcolab.py -O rgcolab.py
# !mkdir -p /content/downloads
RAPIDGATOR_EMAIL = "" #@param {type:"string"}
RAPIDGATOR_PASSWORD = "" #@param {type:"string"}
RAPIDGATOR_LINK = "" #@param {type:"string"}
OUTPUT_DIR = "/content/downloads" #@param {type:"string"}
# !python -u rgcolab.py "$RAPIDGATOR_EMAIL" "$RAPIDGATOR_PASSWORD" "$RAPIDGATOR_LINK" "$OUTPUT_DIR"

# %% [markdown]
# Open in Colab: [RapidGator notebook](https://colab.research.google.com/github/rcks750/RapidGator/blob/main/rapidgator_for_colab.ipynb)
